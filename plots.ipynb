# %%
# The new format for plots

import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

with open('data/frequencies_cos8.npy', 'rb') as f:
    t8 = np.load(f)
    o8 = np.load(f)

with open('data/frequencies_cos5.npy', 'rb') as f:
    t5 = np.load(f)
    o5 = np.load(f)

with open('data/frequencies_cos3.npy', 'rb') as f:
    t3 = np.load(f)
    o3 = np.load(f)

with open('data/temperatures_cos8.npy', 'rb') as f:
    eff_temp8 = np.load(f)
    temp_sys8 = np.load(f)
    env_temp8 = np.load(f)

with open('data/temperatures_cos5.npy', 'rb') as f:
    eff_temp5 = np.load(f)
    temp_sys5 = np.load(f)
    env_temp5 = np.load(f)

with open('data/temperatures_cos3.npy', 'rb') as f:
    eff_temp3 = np.load(f)
    temp_sys3 = np.load(f)
    env_temp3 = np.load(f)

t = t3  # cos3/5/8 share the same time axis

plt.rcParams.update({'font.size': 25})
fig = plt.figure( figsize=(30, 12))

gs = GridSpec(2, 6, hspace = 0, wspace = 0.5)
gs.update(left = 0.1, right = 0.95, top = 0.55, bottom = 0.1)

ylabels = 1.15

ax4 = fig.add_subplot(gs[0:, 4:6])
#ax4.plot(t, env_temp8, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.6, alpha = 0.8)
ax4.plot(t, eff_temp8/env_temp8, color = '#DE9E46', linewidth = 5)
ax4.plot(t, temp_sys8/env_temp8, color = '#2D8077', linewidth = 7)
#plt.tick_params('y', labelleft=False)
ax4.tick_params(axis = 'both', direction='out', length=6, width=2)
ytick = np.array([0.9, 1.0, 1.1])
ax4.set_yticks(ytick, labels = [y for y in ytick])
xtick = np.array([0, 100, 200, 300, 400, 500])
ax4.set_xticks(xtick, labels = [int(y * 10**(-2)) for y in xtick])
plt.text(460, ylabels, '(f)')
plt.text(250, ylabels, '$N = 7$')
ax4.set_xlabel(r'$\omega_s t$')

ax3 = fig.add_subplot(gs[0:, 2:4], sharex = ax4, sharey = ax4)
#ax3.plot(t, env_temp5, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.6, alpha = 0.8)
ax3.plot(t, eff_temp5/env_temp5, color = '#DE9E46', linewidth = 5)
ax3.plot(t, temp_sys5/env_temp5, color = '#2D8077', linewidth = 7)
ax3.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.ylim([0.88, 1.16])
#plt.tick_params('y', labelleft=False)
plt.text(460, ylabels, '(d)')
plt.text(250, ylabels, '$N = 4$')
ax3.set_xlabel(r'$\omega_s t$')

ax2 = fig.add_subplot(gs[0:, 0:2], sharex = ax4, sharey = ax4)
#ax2.plot(t, env_temp3, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.6, alpha = 0.8)
ax2.plot(t, eff_temp3/env_temp3,  color = '#DE9E46', linewidth = 5)
ax2.plot(t, temp_sys3/env_temp3, color = '#2D8077', linewidth = 7)
ax2.tick_params(axis = 'both', direction='out', length=6, width=2)
ax2.set_ylabel('$T_s/T_e$')
plt.text(460, ylabels, '(b)')
plt.text(250, ylabels, '$N = 2$')
ax2.set_xlabel(r'$\omega_s t$')

gs2 = GridSpec(2, 6, hspace = 0, wspace = 0.5)
gs2.update(left = 0.1, right = 0.95, top = 1, bottom = 0.6)
ax1 = fig.add_subplot(gs2[0:, 0:2], sharex = ax2)
ax1.plot(t3, o3, color = 'k', linewidth = 2, alpha = 0.7)
#ytick_u = np.array([0.6, 1.0, 1.4])
#ax1.set_yticks(ytick_u, labels = [y for y in ytick_u])
ax1.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.tick_params('x', labelbottom=False)
plt.text(460, 1.4, '(a)')
ax1.set_ylabel('$\omega_j/\omega_s$')

ax12 = fig.add_subplot(gs2[0:, 2:4], sharex = ax3, sharey = ax1)
ax12.plot(t5, o5, color = 'k', linewidth = 2, alpha = 0.7)
ax12.tick_params(axis = 'both', direction='out', length=6, width=2)
#plt.tick_params('y', labelleft=False)
plt.tick_params('x', labelbottom=False)
plt.text(460, 1.4, '(c)')

ax13 = fig.add_subplot(gs2[0:, 4:6], sharex = ax4, sharey = ax1)
ax13.plot(t8, o8, color = 'k', linewidth = 2, alpha = 0.7)
ax13.tick_params(axis = 'both', direction='out', length=6, width=2)
#plt.tick_params('y', labelleft=False)
plt.tick_params('x', labelbottom=False)
plt.text(460, 1.4, '(e)')


plt.xlim([0, 506])

plt.tight_layout()
plt.savefig('cosine_n_alt_f.svg', dpi = 150, pad_inches=0,bbox_inches='tight')
plt.show()

# %%
# the y axis for the plot below, much better to have Ts/effective temperature than Ts/T(env) because the whole point is to not be at the environment temperature


import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

with open('data/frequencies_constant8.npy', 'rb') as f:
    t8 = np.load(f)
    o8 = np.load(f)

with open('data/frequencies_constant5.npy', 'rb') as f:
    t5 = np.load(f)
    o5 = np.load(f)

with open('data/frequencies_constant3.npy', 'rb') as f:
    t3 = np.load(f)
    o3 = np.load(f)

with open('data/temperatures_constant8.npy', 'rb') as f:
    eff_temp8 = np.load(f)
    temp_sys8 = np.load(f)
    env_temp8 = np.load(f)

with open('data/temperatures_constant5.npy', 'rb') as f:
    eff_temp5 = np.load(f)
    temp_sys5 = np.load(f)
    env_temp5 = np.load(f)

with open('data/temperatures_constant3.npy', 'rb') as f:
    eff_temp3 = np.load(f)
    temp_sys3 = np.load(f)
    env_temp3 = np.load(f)

plt.rcParams.update({'font.size': 25})
fig = plt.figure( figsize=(30, 12))

gs = GridSpec(2, 6, hspace = 0, wspace = 0.5)
gs.update(left = 0.1, right = 0.95, top = 0.55, bottom = 0.1)

ylabel_u = 0.98
xlabel_u =155

ax4 = fig.add_subplot(gs[0:, 4:6])
#ax4.plot(t3, env_temp8, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.6, alpha = 0.8)
ax4.plot(t3, eff_temp8/env_temp8, color = '#DE9E46', linewidth = 5)
ax4.plot(t3, temp_sys8/env_temp8, color = '#2D8077', linewidth = 7)
ax4.tick_params(direction='out', length=6, width=2)
xtick = np.array([0, 50, 100, 150])
ax4.set_xticks(xtick, labels = [y * 10**(-2) for y in xtick])
plt.text(xlabel_u, ylabel_u, '(f)')
plt.text(80, ylabel_u, '$N = 7$')
ax4.set_xlabel('$\omega_s t$')

ax3 = fig.add_subplot(gs[0:, 2:4], sharex = ax4, sharey = ax4)
#ax3.plot(t3, env_temp5, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.5, alpha = 0.8)
ax3.plot(t3, eff_temp5/env_temp5, color = '#DE9E46', linewidth = 5)
ax3.plot(t3, temp_sys5/env_temp5, color = '#2D8077', linewidth = 7)
ax3.tick_params(axis = 'both', direction='out', length=6, width=2)
#plt.ylim([0.9, 1.6])
plt.text(xlabel_u, ylabel_u, '(d)')
plt.text(80, ylabel_u, '$N = 4$')
ax3.set_xlabel('$\omega_s t$')

ax2 = fig.add_subplot(gs[0:, 0:2], sharex = ax4, sharey = ax4)
#ax2.plot(t3, env_temp3, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.5, alpha = 0.8)
ax2.plot(t3, eff_temp3/env_temp3,  color = '#DE9E46', linewidth = 5)
ax2.plot(t3, temp_sys3/env_temp3, color = '#2D8077', linewidth = 7)
ax2.tick_params(axis = 'both', direction='out', length=6, width=2)
ax2.set_ylabel('$T_s/T_e$')
plt.text(xlabel_u, ylabel_u, '(b)')
plt.text(80, ylabel_u, '$N = 2$')
ax2.set_xlabel('$\omega_s t$')

gs2 = GridSpec(2, 6, hspace = 0, wspace = 0.5)
gs2.update(left = 0.1, right = 0.95, top = 1, bottom = 0.6)
ax1 = fig.add_subplot(gs2[0:, 0:2], sharex = ax2)
ax1.plot(t3, o3, color = 'k', linewidth = 2, alpha = 0.7)
ax1.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.tick_params('x', labelbottom=False)
plt.text(xlabel_u, 1.9, '(a)')
ax1.set_ylabel('$\omega_j/\omega_s$')

ax12 = fig.add_subplot(gs2[0:, 2:4], sharex = ax3, sharey = ax1)
ax12.plot(t5, o5, color = 'k', linewidth = 2, alpha = 0.7)
ax12.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.tick_params('x', labelbottom=False)
plt.text(xlabel_u, 1.9, '(c)')

ax13 = fig.add_subplot(gs2[0:, 4:6], sharex = ax4, sharey = ax1)
ax13.plot(t8, o8, color = 'k', linewidth = 2, alpha = 0.7)
ax13.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.tick_params('x', labelbottom=False)
plt.text(xlabel_u, 1.9, '(e)')


plt.xlim([0, 168])

plt.tight_layout()
plt.savefig('constant_n_alt.svg', dpi = 150, pad_inches=0, bbox_inches='tight')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

with open('data/frequencies_pulse_pt4.npy', 'rb') as f:
    t8 = np.load(f)
    o8 = np.load(f)

with open('data/frequencies_pulse_pt2.npy', 'rb') as f:
    t5 = np.load(f)
    o5 = np.load(f)

with open('data/frequencies_pulse_pt1.npy', 'rb') as f:
    t3 = np.load(f)
    o3 = np.load(f)

with open('data/temperatures_pulse_pt4.npy', 'rb') as f:
    eff_temp8 = np.load(f)
    temp_sys8 = np.load(f)
    env_temp8 = np.load(f)

with open('data/temperatures_pulse_pt2.npy', 'rb') as f:
    eff_temp5 = np.load(f)
    temp_sys5 = np.load(f)
    env_temp5 = np.load(f)

with open('data/temperatures_pulse_pt1.npy', 'rb') as f:
    eff_temp3 = np.load(f)
    temp_sys3 = np.load(f)
    env_temp3 = np.load(f)

plt.rcParams.update({'font.size': 25})
fig = plt.figure( figsize=(10, 12))

ancilla_N_x = 50
ancilla_N_y = 1.2
freq_x = 92
freq_y = 1.55
xlimit = 101

gs = GridSpec(3, 4, hspace = 0, wspace = 0.5)
gs.update(left = 0.1, right = 0.95, top = 0.55, bottom = 0.1)

ax2 = fig.add_subplot(gs[0:, 0:])
#ax2.plot(t3, env_temp3, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.6, alpha = 0.8)
#ax2.plot(t3, eff_temp3/env_temp3,  color = '#DE9E46', linewidth = 5)
ax2.plot(t3, eff_temp3/env_temp3, color = '#DE9E46', linewidth = 7)
ax2.plot(t3, temp_sys8/env_temp8, color = '#50b498', linewidth = 7)
ax2.plot(t3, temp_sys5/env_temp5, color = '#9cdba6', linewidth = 7)
ax2.plot(t3, temp_sys3/env_temp3, color = '#2D8077', linewidth = 7)
ax2.tick_params(axis = 'both', direction='out', length=6, width=2)
ax2.set_ylabel('$T_{s/0}/T_e$')
plt.text(freq_x, ancilla_N_y, '(b)')
#plt.ylim([0.87, 1.11])
plt.xlim([0, xlimit])
plt.text(ancilla_N_x, ancilla_N_y, '\u03B1 = 0.1')
ax2.set_xlabel('$\omega_s t$')

gs2 = GridSpec(1, 4, hspace = 0, wspace = 0.5)
gs2.update(left = 0.1, right = 0.95, top = 1, bottom = 0.6)

ax1 = fig.add_subplot(gs2[0, 0:], sharex = ax2)
ax1.plot(t3, o3, color = 'k', linewidth = 0.7, alpha = 0.7)
ax1.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.tick_params('x', labelbottom=False)
plt.text(freq_x, freq_y, '(a)')
ax1.set_ylabel('$\omega_j/\omega_s$')

plt.tight_layout()
plt.savefig('fig6_2.svg', dpi = 150, pad_inches=0, bbox_inches='tight')
plt.show()

# %%
# the y axis for the plot below, much better to have Ts/effective temperature than Ts/T(env) because the whole point is to not be at the environment temperature


import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

with open('data/frequencies_fig_1.npy', 'rb') as f:
    t8 = np.load(f)
    o8 = np.load(f)

with open('data/temperatures_fig_1.npy', 'rb') as f:
    eff_temp8 = np.load(f)
    temp_sys8 = np.load(f)
    env_temp8 = np.load(f)


plt.rcParams.update({'font.size': 25})
fig = plt.figure( figsize=(10, 6))

gs = GridSpec(2, 6, hspace = 0, wspace = 8)
gs.update(left = 0.1, right = 0.95, top = 0.55, bottom = 0.1)

ylabel_u = 0.98
xlabel_u =127

ax2 = fig.add_subplot(gs[0:, 3:])
#ax2.plot(t3, env_temp3, color = 'red', ls = '--', dashes=(13, 3), linewidth = 0.5, alpha = 0.8)
ax2.plot(t8, eff_temp8/env_temp8,  color = '#DE9E46', linewidth = 5)
ax2.plot(t8, temp_sys8/env_temp8, color = '#2D8077', linewidth = 7)
ax2.tick_params(axis = 'both', direction='out', length=6, width=2)
ax2.set_ylabel('$T_s/T_e$')
plt.text(xlabel_u, ylabel_u, '(b)')
ax2.set_xlabel('$\omega_s t$')
ax2.set_ylim([0.53, 1.06])

ax1 = fig.add_subplot(gs[0:, 0:3], sharex = ax2)
ax1.plot(t8, o8, color = 'k', linewidth = 2, alpha = 0.7)
ax1.tick_params(axis = 'both', direction='out', length=6, width=2)
plt.text(xlabel_u, 1.9, '(a)')
ax1.set_ylabel('$\omega_j/\omega_s$')


plt.xlim([0, 135])

#plt.tight_layout()
plt.savefig('constant_fig_1.svg', dpi = 150, pad_inches=0, bbox_inches='tight')
plt.show()
